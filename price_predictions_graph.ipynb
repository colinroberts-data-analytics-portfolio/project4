# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
future_predictions_df = pd.read_csv('Resources/future_predictions.csv')

# %%
future_predictions_df
# Out:
#                Make    Model  predicted_price_in_5_years
# 0     Mercedes-Benz  S-Class                   10011.375
# 1            Nissan  Magnite                   60567.210
# 2               BMW       X1                   11712.780
# 3               Kia   Seltos                   57260.250
# 4             Skoda   Superb                   50209.830
# ...             ...      ...                         ...
# 1532        Hyundai    Creta                    9039.150
# 1533        Renault     KWID                    7738.560
# 1534          Honda     WR-V                   53162.865
# 1535     Volkswagen     Polo                   51709.005
# 1536         Maruti    Swift                   52669.980
#
# [1537 rows x 3 columns]

# %%
# Lowest ---------------------------------
future_predictions_df = pd.read_csv('future_predictions.csv')

top_20_predictions = future_predictions_df.sort_values(by='predicted_price_in_5_years', ascending=True).head(20)

plt.figure(figsize=(12, 8))

plt.barh(top_20_predictions['Make'] + ' ' + top_20_predictions['Model'], top_20_predictions['predicted_price_in_5_years'], color='skyblue')

plt.xlabel('Predicted Price in 5 Years')
plt.ylabel('Car Make and Model')
plt.title('Top 20 Predicted Car Prices in 5 Years (Ascending Order)')

plt.show()

# %%
top_20_predictions = future_predictions_df.sort_values(by='predicted_price_in_5_years', ascending=False).head(20)

# %%
plt.barh(top_20_predictions['Make'] + ' ' + top_20_predictions['Model'], top_20_predictions['predicted_price_in_5_years'], color='skyblue')
# Out:
# <BarContainer object of 20 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt

future_predictions_df = pd.read_csv('future_predictions.csv')

top_20_predictions = future_predictions_df.sort_values(by='predicted_price_in_5_years', ascending=False).head(20)

plt.figure(figsize=(12, 8))

plt.barh(top_20_predictions['Make'] + ' ' + top_20_predictions['Model'], top_20_predictions['predicted_price_in_5_years'], color='skyblue')

plt.xlabel('Predicted Price in 5 Years')
plt.ylabel('Car Make and Model')
plt.title('Top 20 Predicted Car Prices in 5 Years (Descending Order)')

plt.gca().invert_yaxis()

plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 8))

plt.barh(top_20_predictions['Make'] + ' ' + top_20_predictions['Model'], top_20_predictions['predicted_price_in_5_years'], color='skyblue')

plt.xlabel('Predicted Price in 5 Years (Log Scale)')
plt.ylabel('Car Make and Model')
plt.title('Top 20 Predicted Car Prices in 5 Years (Descending Order)')

plt.xscale('log')

plt.gca().invert_yaxis()

# Show the plot
plt.show()
