# %%
# importing section 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy as sp

# %%
usedCar_df = pd.read_csv('resources/Used_Care_Price_Dataset.csv') 

usedCar_df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            17-Jul      Comprehensive    Petrol      5       56000
# 1            21-Jan      Comprehensive    Petrol      5       30615
# 2            18-Sep      Comprehensive    Diesel      5       24000
# 3            19-Dec      Comprehensive    Petrol      5       18378
# 4            19-Aug      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %%
usedCar_df['price(in lakhs)'] = usedCar_df['price(in lakhs)'].apply(lambda x: int(x))

usedCar_df['price(in lakhs)'] = usedCar_df['price(in lakhs)'].apply(lambda x: "${:,.2f}".format(x))

usedCar_df.dtypes
# Out:
# Unnamed: 0              int64
# car_name               object
# registration_year      object
# insurance_validity     object
# fuel_type              object
# seats                   int64
# kms_driven              int64
# ownsership             object
# transmission           object
# manufacturing_year     object
# mileage(kmpl)         float64
# engine(cc)            float64
# max_power(bhp)        float64
# torque(Nm)            float64
# price(in lakhs)        object
# dtype: object

# %%
usedCar_df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            17-Jul      Comprehensive    Petrol      5       56000
# 1            21-Jan      Comprehensive    Petrol      5       30615
# 2            18-Sep      Comprehensive    Diesel      5       24000
# 3            19-Dec      Comprehensive    Petrol      5       18378
# 4            19-Aug      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...
